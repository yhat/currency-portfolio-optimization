# %% [markdown]
# # Currency Portfolio Optimization

# %% [markdown]
# Download 100 months of data from [FRB H10: Data Download Program](http://www.federalreserve.gov/datadownload/Build.aspx?rel=H10).
#
# The first 6 rows are row oriented data and the remaining are column oriented. We read these into two different data frames.

# %%
import csv
import pandas

raw_data = [row for row in csv.reader(open('2014-12-28-fed-monthly-currency-data.csv'))]

# Transpose head data and turn it into a data frame
head_data = [[] for _ in range(len(raw_data[0]))]
for row in raw_data[:6]:
    for j, val in enumerate(row):
        head_data[j].append(val)
    
metadata = pandas.DataFrame.from_records(data=head_data[1:], columns=head_data[0])

# Filter out NA currencies
metadata = metadata[metadata['Currency:'] != 'NA']
metadata
# Out:
#                                    Series Description              Unit:  \
# 3   AUSTRALIA -- SPOT EXCHANGE RATE, US$/AUSTRALIA...  Currency:_Per_AUD
# 4                     SPOT EXCHANGE RATE - EURO AREA   Currency:_Per_EUR
# 5   NEW ZEALAND -- SPOT EXCHANGE RATE, US$/NZ$ (RE...  Currency:_Per_NZD
# 6   United Kingdom -- Spot Exchange Rate, US$/Poun...  Currency:_Per_GBP
# 7            BRAZIL -- SPOT EXCHANGE RATE, REAIS/US$   Currency:_Per_USD
# 8       CANADA -- SPOT EXCHANGE RATE, CANADIAN $/US$   Currency:_Per_USD
# 9              CHINA -- SPOT EXCHANGE RATE, YUAN/US$   Currency:_Per_USD
# 10         DENMARK -- SPOT EXCHANGE RATE, KRONER/US$   Currency:_Per_USD
# 11          HONG KONG -- SPOT EXCHANGE RATE, HK$/US$   Currency:_Per_USD
# 12            INDIA -- SPOT EXCHANGE RATE, RUPEES/US$  Currency:_Per_USD
# 13              JAPAN -- SPOT EXCHANGE RATE, YEA/US$   Currency:_Per_USD
# 14              KOREA -- SPOT EXCHANGE RATE, WON/US$   Currency:_Per_USD
# ...

# %%
# For convenience, we'll create a list of the country names for the currencies.
countries = []
for c in metadata['Series Description']:
    c = c.upper()
    c = c.split(' -- ')[0]
    c = c.split(' - ')[0]
    countries.append(c)
countries[1] = 'EURO AREA'
countries
# Out:
# ['AUSTRALIA',
#  'EURO AREA',
#  'NEW ZEALAND',
#  'UNITED KINGDOM',
#  'BRAZIL',
#  'CANADA',
#  'CHINA',
#  'DENMARK',
#  'HONG KONG',
#  'INDIA',
#  'JAPAN',
#  'KOREA',
#  'MALAYSIA',
#  'MEXICO',
#  'NORWAY',
#  'SWEDEN',
#  'SOUTH AFRICA',
#  'SINGAPORE',
#  'SRI LANKA',
#  'SWITZERLAND',
#  'TAIWAN',
#  'THAILAND',
#  'VENEZUELA']

# %%
# Read the rest of the data into a data frame
exchange_rates = pandas.DataFrame.from_records(data=raw_data[6:], columns=raw_data[5])

# Filter out NA currencies.
exchange_rates = exchange_rates[['Time Period'] + list(metadata['Time Period'])]
exchange_rates.tail()
# Out:
#    Time Period RXI$US_N.M.AL RXI$US_N.M.EU RXI$US_N.M.NZ RXI$US_N.M.UK  \
# 95     2014-08        0.9309        1.3315        0.8437        1.6700
# 96     2014-09        0.9042        1.2889        0.8134        1.6290
# 97     2014-10        0.8781        1.2677        0.7876        1.6074
# 98     2014-11        0.8644        1.2473        0.7834        1.5771
# 99     2014-12        0.8302        1.2389        0.7765        1.5678
#
#    RXI_N.M.BZ RXI_N.M.CA RXI_N.M.CH RXI_N.M.DN RXI_N.M.HK    ...      \
# 95     2.2685     1.0926     6.1541     5.5987     7.7504    ...
# 96     2.3379     1.1011     6.1382     5.7757     7.7526    ...
# 97     2.4495     1.1212     6.1251     5.8723     7.7572    ...
# 98     2.5527     1.1325     6.1249     5.9660     7.7543    ...
# 99     2.6278     1.1496     6.1781     6.0049     7.7528    ...
#
#    RXI_N.M.MX RXI_N.M.NO RXI_N.M.SD RXI_N.M.SF RXI_N.M.SI RXI_N.M.SL  \
# 95    13.1436     6.1935     6.8983    10.6632     1.2484   130.1748
# ...

# %%
# Convert the exchange rate data frame into percentage returns.

# There are two types of conversions we are concerned with: 
#
# 1. metadata['Currency:'] == 'USD'
#    value = USD per 1 unit of other currency
#
# 2. metadata['Currency:'] != 'USD'
#    value = units of other currency per 1 USD

rows = []
for i in range(len(exchange_rates)-1):
    row = {}
    for tp, cur in zip(metadata['Time Period'], metadata['Currency:']):
        x1 = float(exchange_rates[tp][i])
        x2 = float(exchange_rates[tp][i+1])
    
        if cur == 'USD':
            x1 = 1.0 / x1
            x2 = 1.0 / x2
        
        # Returns are in units of %.
        row[tp] = 100 * (x1 - x2) / x2
    rows.append(row)

returns = pandas.DataFrame(data=rows, columns=list(metadata['Time Period']))
returns.tail()
# Out:
#     RXI$US_N.M.AL  RXI$US_N.M.EU  RXI$US_N.M.NZ  RXI$US_N.M.UK  RXI_N.M.BZ  \
# 94      -0.852061      -1.610877      -2.877863      -2.144615   -1.952832
# 95      -2.868192      -3.199399      -3.591324      -2.455090   -2.968476
# 96      -2.886530      -1.644813      -3.171871      -1.325967   -4.556032
# 97      -1.560187      -1.609214      -0.533266      -1.885032   -4.042778
# 98      -3.956502      -0.673455      -0.880776      -0.589690   -2.857904
#
#     RXI_N.M.CA  RXI_N.M.CH  RXI_N.M.DN  RXI_N.M.HK  RXI_N.M.IN     ...      \
# 94   -1.711514    0.719845   -1.589655   -0.002581   -1.278382     ...
# 95   -0.771955    0.259034   -3.064564   -0.028378   -0.039082     ...
# 96   -1.792722    0.213874   -1.645011   -0.059300   -0.764583     ...
# 97   -0.997792    0.003265   -1.570567    0.037399   -0.512298     ...
# 98   -1.487474   -0.861106   -0.647804    0.019348   -1.211577     ...
#
#     RXI_N.M.MX  RXI_N.M.NO  RXI_N.M.SD  RXI_N.M.SF  RXI_N.M.SI  RXI_N.M.SL  \
# ...

# %%
# Means are the expected returns for each currency.

exp_returns = pandas.concat({'mean': returns.mean(), 'variance': returns.var()}, axis=1)
exp_returns
# Out:
#                    mean   variance
# RXI$US_N.M.AL  0.152151  10.996718
# RXI$US_N.M.EU  0.002683   5.928188
# RXI$US_N.M.NZ  0.220217   9.690793
# RXI$US_N.M.UK -0.159779   5.098969
# RXI_N.M.BZ    -0.128507  12.743632
# RXI_N.M.CA    -0.007877   4.380697
# RXI_N.M.CH     0.253968   0.212987
# RXI_N.M.DN     0.004799   5.810684
# RXI_N.M.HK     0.003935   0.014761
# RXI_N.M.IN    -0.283975   4.784800
# RXI_N.M.JA     0.016618   6.449970
# RXI_N.M.KO    -0.110786   7.580272
# RXI_N.M.MA     0.068651   2.424957
# RXI_N.M.MX    -0.235747   7.786813
# RXI_N.M.NO    -0.065996   7.727538
# RXI_N.M.SD     0.001158   7.832406
# RXI_N.M.SF    -0.369169  12.837594
# RXI_N.M.SI     0.195880   1.596186
# RXI_N.M.SL    -0.240545   1.289438
# RXI_N.M.SZ     0.286951   6.917752
# RXI_N.M.TA     0.059511   1.299676
# RXI_N.M.TH     0.144215   2.731771
# RXI_N.M.VE    -0.914809  25.526367

# %%
# Expected returns farther from 0 appear to have higher variance.
# %matplotlib inline
import seaborn
seaborn.regplot('mean', 'variance', exp_returns)

# %%
# That's quite an outlier there. What does the rest of the data look like?

exp_returns_without_ve = exp_returns[exp_returns.index != 'RXI_N.M.VE']
seaborn.regplot('mean', 'variance', exp_returns)
seaborn.regplot('mean', 'variance', exp_returns_without_ve)

# %%
# So let's say we want to maximize our return in US dollars. The simplest approach is to 
# select the currency that has the best expected return, and convert all our money to it.

countries[list(exp_returns.index).index(exp_returns['mean'].idxmax())]
# Out:
# 'SWITZERLAND'

# %%
# This tells us to invest all our money in Swiss Francs for a 0.2% expected return monthly.
# The data gives us a 95% confidence interval that the expected monthly return of investing 
# in Swiss Francs is between -0.2% and 0.8%.

import math
n = len(exchange_rates)
sz_mean = exp_returns['mean']['RXI_N.M.SZ']
sz_sd = math.sqrt(exp_returns['variance']['RXI_N.M.SZ'])
sz_ci = (sz_mean-1.96*sz_sd/math.sqrt(n), sz_mean+1.96*sz_sd/math.sqrt(n))
print 'Monthly expected return (Swiss Francs): %0.3f%%' % sz_mean
print '95%% confidence interval on expected return: (%0.3f%%, %.03f%%)' % sz_ci
# Out:
# Monthly expected return (Swiss Francs): 0.287%
# 95% confidence interval on expected return: (-0.229%, 0.802%)

# %%
# It's important to note that this is our confidence in the _expected return_, not even in
# any particular return. That means that the expected return of our highest yielding currency
# could be negative or it could be positive. We don't really know. So we could end up deciding
# to go all in on Swiss Francs, only to discover that should expect to lose 0.2% of our money
# in relation to the US dollar every month.

# We'd like to do better, obviously. And there's another piece of information we have that
# might allow us to: how the different currencies relate to each other.

# %%
# Get the covariance matrix for our returns. This is normalized by N-1.
# As expected, the diagonal contains the variance for each individual currency.

returns_cov = returns.cov()
returns_cov.head()
# Out:
#                RXI$US_N.M.AL  RXI$US_N.M.EU  RXI$US_N.M.NZ  RXI$US_N.M.UK  \
# RXI$US_N.M.AL      10.996718       5.181782       8.654762       4.457704
# RXI$US_N.M.EU       5.181782       5.928188       4.487890       3.659548
# RXI$US_N.M.NZ       8.654762       4.487890       9.690793       4.330531
# RXI$US_N.M.UK       4.457704       3.659548       4.330531       5.098969
# RXI_N.M.BZ          9.789818       4.686754       8.130412       4.301933
#
#                RXI_N.M.BZ  RXI_N.M.CA  RXI_N.M.CH  RXI_N.M.DN  RXI_N.M.HK  \
# RXI$US_N.M.AL    9.789818    5.421746    0.194428    5.166875    0.028496
# RXI$US_N.M.EU    4.686754    2.467804    0.313081    5.867674    0.038117
# RXI$US_N.M.NZ    8.130412    4.268307    0.129303    4.466514    0.017975
# RXI$US_N.M.UK    4.301933    2.573100    0.137068    3.632088    0.012420
# RXI_N.M.BZ      12.743632    5.433992    0.279201    4.689891   -0.034405
#
# ...

# %%
# Alpha represents our averseness to risk. We solve the model for various levels of alpha
# to plot expected returns and variances of those returns.
from cvxopt import matrix, solvers
import numpy

q = matrix(-exp_returns['mean'].as_matrix())
G = matrix(0.0, (len(q),len(q)))
G[::len(q)+1] = -1.0
h = matrix(0.0, (len(q),1))
A = matrix(1.0, (1,len(q)))
b = matrix(1.0)

portfolios = []
portfolio_returns = []
portfolio_variances = []

alphas = range(21)
for a in alphas:
    P = matrix(a * returns_cov.as_matrix())
    solution = solvers.qp(P, q, G, h, A, b)
    
    portfolios.append(solution['x'])
    portfolio_returns.append(exp_returns['mean'].dot(solution['x'])[0])
    portfolio_variances.append(sum(solution['x'] * returns_cov.as_matrix().dot(solution['x']))[0])
# Out:
#      pcost       dcost       gap    pres   dres
#  0: -1.4109e+00 -1.2870e+00  6e+01  9e+00  5e+00
#  1: -1.8207e-02 -1.2285e+00  1e+00  4e-15  9e-16
#  2: -6.2411e-02 -2.9637e-01  2e-01  1e-15  9e-16
#  3: -1.4238e-01 -3.5309e-01  2e-01  5e-16  6e-16
#  4: -2.8201e-01 -2.9496e-01  1e-02  1e-16  4e-16
#  5: -2.8688e-01 -2.8703e-01  2e-04  4e-16  5e-16
#  6: -2.8695e-01 -2.8695e-01  2e-06  8e-17  3e-16
#  7: -2.8695e-01 -2.8695e-01  2e-08  2e-16  3e-16
# Optimal solution found.
#      pcost       dcost       gap    pres   dres
#  0: -1.7310e-01 -1.2428e+00  4e+01  5e+00  6e+00
#  1: -4.7542e-03 -9.2263e-01  2e+00  2e-01  2e-01
#  2:  3.8252e-02 -2.6797e-01  4e-01  3e-02  3e-02
#  3: -9.4620e-02 -1.8481e-01  9e-02  2e-16  8e-16
#  4: -1.4057e-01 -1.5061e-01  1e-02  2e-16  7e-16
#  5: -1.4747e-01 -1.4833e-01  9e-04  1e-16  7e-16
#  6: -1.4822e-01 -1.4825e-01  3e-05  2e-16  6e-16
#  7: -1.4825e-01 -1.4825e-01  1e-06  3e-16  5e-16
#  8: -1.4825e-01 -1.4825e-01  2e-08  2e-16  4e-16
# ...

# %%
# Now we have an efficient frontier (Pareto optimality) showing the 
# trade-off of risk versus return.

from matplotlib import pyplot
pyplot.plot(alphas, portfolio_returns, 'o-')
pyplot.axis([-1, 21, 0.0, 0.3])
pyplot.title('Efficient Frontier for Currency Portfolios')
pyplot.text(9, -0.05, 'alpha')
pyplot.text(-4, 0.18, '% Return', rotation='vertical')

# %%
pyplot.plot(portfolio_returns, portfolio_variances, 'o-')
pyplot.axis([0, 0.3, -0.5, 7.5])
pyplot.title('Efficient Frontier for Currency Portfolios')
pyplot.text(.1, -2, 'Expected Return (%)')
pyplot.text(-0.025, 5, 'Portfolio Return Variance', rotation='vertical')

# %%
# We print out all the portfolios available to us.
from operator import itemgetter

for i, (p, r, v) in enumerate(zip(portfolios, portfolio_returns, portfolio_variances)):
    print 'Portfolio %d: expected monthly return=%.03f%%, variance=%.03f' % (i, r, v)
    for j, investment in sorted(enumerate(p), key=itemgetter(1), reverse=True):
        # Ignore values that appear to have converged to 0.
        if investment > 10e-5:
            print '\t%5.02f%% %s' % (investment*100, countries[j])
    print
# Out:
# Portfolio 0: expected monthly return=0.287%, variance=6.918
# 	100.00% SWITZERLAND
#
# Portfolio 1: expected monthly return=0.251%, variance=0.206
# 	97.68% CHINA
# 	 2.32% THAILAND
#
# Portfolio 2: expected monthly return=0.158%, variance=0.082
# 	60.55% CHINA
# 	37.25% HONG KONG
# 	 2.20% THAILAND
#
# Portfolio 3: expected monthly return=0.113%, variance=0.044
# 	55.60% HONG KONG
# 	42.57% CHINA
# 	 1.83% THAILAND
#
# Portfolio 4: expected monthly return=0.090%, variance=0.030
# 	64.78% HONG KONG
# 	33.57% CHINA
# 	 1.65% THAILAND
#
# Portfolio 5: expected monthly return=0.077%, variance=0.024
# 	70.28% HONG KONG
# 	28.18% CHINA
# 	 1.54% THAILAND
#
# Portfolio 6: expected monthly return=0.067%, variance=0.021
# 	73.95% HONG KONG
# 	24.58% CHINA
# 	 1.47% THAILAND
#
# Portfolio 7: expected monthly return=0.061%, variance=0.019
# 	76.57% HONG KONG
# 	22.01% CHINA
# 	 1.41% THAILAND
#
# Portfolio 8: expected monthly return=0.056%, variance=0.018
# 	78.54% HONG KONG
# 	20.08% CHINA
# ...
